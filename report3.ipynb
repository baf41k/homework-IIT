# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>1. Титульный лист</font>

# %% [markdown]
# <font size="2" color="black" face="Times"><p align="center">
# <b>МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ
# </b></p></font>
# <hr>
#
# <font size="2" color="black" face="Times"><p align="center">
# <b>ОРДЕНА ТРУДОВОГО КРАСНОГО ЗНАМЕНИ ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ
# <br>«МОСКОВСКИЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕТ СВЯЗИ И ИНФОРМАТИКИ»
# </b></p></font>
# <hr>
#
# <font size="2" color="black" face="Times"><p align="center">
# Факультет «Радио и телевидение»
# <br>Кафедра «Телевидения и Звукового Вещания имени С. И. Катаева.»
# </p></font>
# <hr>
# <br><br>
#
# <font size="2" color="black" face="Times"><p align="center">
# <br>Отчет о выполнении:
# <br>
# <font size="3">Лабораторной работы № 11</font>
# <br>
# <br>по дисциплине:
# <br>
# <font size="3">«Введение в информационные технологии»</font>
# <br>
# <br>На тему:
# <br>
# <font size="3">«Системы контроля версий»</font>
# <br><br><br><br>
# <p align="right"><font size="2">Выполнил: Кардаманов Генрих Андреевич
# <br> группа: БИК-2409
# <br>Проверил: ассистент каф. ТиЗВ: Кудряшов В. В.</font></p>
# <br><br>
# <p align="center"><font size="2">Москва 2024
# </font></p>

# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>2. Содержание</font>

# %% [markdown]
# <font size="3" color="black" face="Times">
# <a href = '#part3'>3. Теоретическая часть</a><br>
# <a href = '#part31'>&emsp;3.1. Разбор теоретических вопросов</a><br>
# <a href = '#part32'>&emsp;3.2. Используемые источники</a><br>
#
# <a href = '#part4'>4. Постановка задания</a><br>
# <a href = '#part41'>&emsp;4.1. Задание</a><br>
# <a href = '#part42'>&emsp;4.2. Цель работы</a><br>
# <a href = '#part43'>&emsp;4.3. Планирование задач</a><br>
# <a href = '#part44'>&emsp;4.4. Расчет исходных данных</a><br>
#
# <a href = '#part5'>5. Ход работы</a><br>
# <a href = '#part51'>&emsp;5.1. Задача 1</a><br>
# <a href = '#part52'>&emsp;5.2. Задача 2</a><br>
# <a href = '#part53'>&emsp;5.3. Задача 3</a><br>
# <a href = '#part54'>&emsp;5.4. Задача 4</a><br>
# <a href = '#part55'>&emsp;5.5. Задача 5</a><br>
# <a href = '#part56'>&emsp;5.6. Задача 6</a><br>
# <a href = '#part57'>&emsp;5.7. Задача 7</a><br>
# <a href = '#part58'>&emsp;5.8. Задача 8</a><br>
# <a href = '#part59'>&emsp;5.9. Задача 9</a><br>
# <a href = '#part6'>6. Результаты</a><br>
# <a href = '#part61'>&emsp;6.1. Выводы</a><br>
# </font>

# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>3. Теоретическая часть</font><a name = 'part3'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;3.1. Разбор теоретических вопросов</b></font><a name = 'part31'>

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.32.18 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.33.02 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.33.52 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.35.00 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.35.32 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.36.09 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.36.57 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 11.37.40 AM.png](data:image/png;base64,...)

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;3.2. Используемые источники</b></font><a name = 'part32'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# <a name = 'liter1'>
# <a href = 'https://gitforwindows.org/'>&emsp;1. Установить GIT [Электронный ресурс]: GIT for windows – URL: https://gitforwindows.org/ (дата обращения: 04.12.2024).</a>
# <br>
# <a name = 'liter2'>
# <a href = 'https://habr.com/ru/post/273897/'>&emsp;2. 	Настройка GIT [Электронный ресурс]:
# HABR – URL: https://habr.com/ru/post/273897/ (дата обращения: 04.12.2024).</a>
# <br>
# <a name = 'liter3'>
# <a href = 'https://habr.com/ru/post/342116/'>&emsp;3. GIT на практике. [Электронный ресурс]:
# HABR: https://habr.com/ru/post/342116/ (дата обращения: 04.12.2024).</a>
# <br>
# <a name = 'liter4'>
# <a href = 'https://smartiqa.ru/courses/git/lesson-6'>&emsp;4. Работа на удаленном репозитории [Электронный ресурс]:
# GIT lesson 6 – URL: https://smartiqa.ru/courses/git/lesson-6 (дата обращения: 04.12.2024).</a>
# <br>
# <a name = 'liter5'>
# <a href = 'https://htmlacademy.ru/blog/git/github-as-hosting'>&emsp;5. Как залить сайт [Электронный ресурс]:
# htmlacademy – URL: https://htmlacademy.ru/blog/git/github-as-hosting (дата обращения: 04.12.2024).</a>
# <br>
# <a name = 'liter6'>
# <a href = 'https://habr.com/ru/post/458006/ '>&emsp;6. Динамические сайты[Электронный ресурс]:
# HABR – URL: https://habr.com/ru/post/458006/  (дата обращения: 04.12.2024).</a>
# <br>
#
#
#
# </font>

# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>4. Постановка задания</font><a name = 'part4'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;4.1. Задание</b></font><a name = 'part41'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Подготовить общий набор данных по 10 вариантов различного написания соответствующих разным группам и написать для поиска под каждую из групп свое регулярное выражение:
# <ol>
# <li>Установить GIT</li>
# <li>Создать локальный репозиторий</li>
# <li>Создать файл отчета по выполнению практической работы и поместить его в репозиторий</li>
# <li>Зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT</li>
# <li>Создать ветку отчета в GIT, добавьте описания шагов в отчет и создать версию отчета в новой ветке</li>
# <li>Слить последнее изменение отчета в основную ветку</li>
# <li>Зарегистрироваться на github (или использовать уже существующий аккаунт), создать проект «homework IIT», залить содержимое из локального репозитория в проект на githab</li>
# <li>Разместить на github ранее созданный статический сайт</li>
# <li>Доп. задание – Разметить на github ранее созданный динамический сайт</li>
# <li>Завершить отчет, добавив описание всех пунктов</li>
# </ol>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;4.2. Цель работы</b></font><a name = 'part42'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">&emsp;Установка Git и создание репозитория.

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;4.3. Планирование задач</b></font><a name = 'part43'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Подготовить общий набор данных по 10 вариантов различного написания соответствующих разным группам и написать для поиска под каждую из групп свое регулярное выражение:
# <ol>
# <li>Установить GIT</li>
# <li>Создать локальный репозиторий</li>
# <li>Создать файл отчета по выполнению практической работы и поместить его в репозиторий</li>
# <li>Зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT</li>
# <li>Создать ветку отчета в GIT, добавьте описания шагов в отчет и создать версию отчета в новой ветке</li>
# <li>Слить последнее изменение отчета в основную ветку</li>
# <li>Зарегистрироваться на github (или использовать уже существующий аккаунт), создать проект «homework IIT», залить содержимое из локального репозитория в проект на githab</li>
# <li>Разместить на github ранее созданный статический сайт</li>
# <li>Доп. задание – Разметить на github ранее созданный динамический сайт</li>
# <li>Завершить отчет, добавив описание всех пунктов</li>
# </ol>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;4.4. Расчет исходных данных</b></font><a name = 'part44'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# Установка Git https://git-scm.com
# </font>

# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>5. Ход работы</b></font><a name = 'part5'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.1. Задача 1</b></font><a name = 'part51'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# <b>&emsp;Установить Git
# </font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify"> Я использовал MacOS и использовал следующую команду:

# %%
git --version

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 12.12.05 PM.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 1.</b> Результат установки git
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.2. Задача 2</b></font><a name = 'part52'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# <b>&emsp;Создать локальный репозиторий.
# </font>

# %%
#Команда для создания локального репозитория
git init

# %% [markdown]
# ![Снимок экрана 2024-12-09 в 1.22.17 PM.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 2.</b> Результат создания локального репозитория
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.3. Задача 3</b></font><a name = 'part53'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify"><b>
# Создать файл отчета по выполнению практической работы и поместить его в репозиторий

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# Я создал файл отчета поместил его в репозиторий.

# %%
git add report.ipynb

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.4. Задача 4</b></font><a name = 'part54'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify"><b>
# Зафиксировать в отчете все проделанные шаги и создайте версию отчета в GIT

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# Я зафиксировал выполненные шаги с создал версию отчета.

# %% [markdown]
# ![Screenshot 2024-12-09 at 2.47.52 PM.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 3.</b> Создание версии
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.5. Задача 5</b></font><a name = 'part55'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify"><b>
# Создать ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify"> Я создал ветку с назваием low и залил новую версию отчета с добавленными задачами №3 и №4 в новую ветку.

# %%
git branch low #создание ветки low

# %% [markdown]
# ![Screenshot 2024-12-09 at 3.05.43 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-09 at 3.06.24 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-09 at 3.07.07 PM.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 4.</b> Создание ветки и версии
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.6. Задача 6</b></font><a name = 'part56'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.7. Задача 7</b></font><a name = 'part57'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.8. Задача 8</b></font><a name = 'part58'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.9. Задача 9</b></font><a name = 'part59'>

# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>6. Результаты</b></font><a name = 'part6'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;6.1. Выводы</b></font><a name = 'part61'>

# %% [markdown]
# <font size="3" color="black" face="Times"><br>&emsp;В результате выполнения задач создан набор регулярные выражения, с помощью которых можно находить:
# <ul>
# <li>Email адреса</li>
# <li>Названий сайтов</li>
# <li>RGB цвета в 16-ричном виде</li>
# <li>Даты и время</li>
# <li>Цены в рублях</li>
# <li>Часть HTML страницы</li>
# <li>IP адреса V4</li>
# <li>Ссылки URL</li>
# <li>Московские городские номера телефонов</li>
# <li>С помощью ленивого поиска текст в HTML тегах</li>
# <li>протокол в URL</li>
# </ul>
#
# </font>
